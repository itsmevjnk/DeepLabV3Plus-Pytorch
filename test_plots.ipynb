# %% [markdown]
# # Export test results

# %% [markdown]
# ## Module imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load results file

# %%
df = pd.read_csv('results.csv')
df
# Out:
#    Unnamed: 0                      Model  Pixel accuracy  Mean class accuracy  \
# 0           0           resnet50_scratch        0.983489             0.847098
# 1           1          mobilenet_scratch        0.986057             0.862179
# 2           2        mobilenet_separable        0.985305             0.858674
# 3           3         mobilenet_transfer        0.983391             0.837781
# 4           4  mobilenet_transfer_single        0.958293             0.725967
#
#    Mean IoU  0 accuracy     0 IoU  1 accuracy     1 IoU  2 accuracy  ...  \
# 0  0.486296    0.992009  0.984582    0.920559  0.320905    0.950133  ...
# 1  0.459292    0.994078  0.987368    0.945917  0.302353    0.949557  ...
# 2  0.456759    0.993340  0.986627    0.947707  0.282977    0.949489  ...
# 3  0.472536    0.992718  0.984702    0.930018  0.283424    0.937549  ...
# 4  0.199110    0.969334  0.963586    0.919386  0.139202    0.905658  ...
#
# ...

# %% [markdown]
# ## Per-object statistics

# %%
CLASSES = {
     0: 'Background',
     1: '002_master_chef_can',
     2: '003_cracker_box',
     3: '004_sugar_box',
     4: '005_tomato_soup_can',
     5: '006_mustard_bottle',
     6: '007_tuna_fish_can',
     7: '008_pudding_box',
     8: '009_gelatin_box',
     9: '010_potted_meat_can',
    10: '011_banana',
    11: '019_pitcher_base',
    12: '021_bleach_cleanser',
    13: '024_bowl',
    14: '025_mug',
    15: '035_power_drill',
    16: '036_wood_block',
    17: '037_scissors',
    18: '040_large_marker',
    # 19: '051_large_clamp',
    20: '052_extra_large_clamp',
    21: '061_foam_brick',
    22: 'Hand'
}

# %%
data = []
for obj, obj_name in CLASSES.items():
    row = {
        'Object': obj_name
    }
    for idx, model in enumerate(df['Model']):
        row[model] = df.loc[idx, f'{obj} accuracy']
    data.append(row)
df_objects = pd.DataFrame(data)
df_objects
# Out:
#                    Object  resnet50_scratch  mobilenet_scratch  \
# 0              Background          0.992009           0.994078
# 1     002_master_chef_can          0.920559           0.945917
# 2         003_cracker_box          0.950133           0.949557
# 3           004_sugar_box          0.911811           0.925318
# 4     005_tomato_soup_can          0.821777           0.817334
# 5      006_mustard_bottle          0.927345           0.921761
# 6       007_tuna_fish_can          0.748004           0.770842
# 7         008_pudding_box          0.855618           0.890151
# 8         009_gelatin_box          0.803787           0.856086
# 9     010_potted_meat_can          0.876860           0.863397
# 10             011_banana          0.821959           0.850199
# 11       019_pitcher_base          0.937052           0.944791
# 12    021_bleach_cleanser          0.895401           0.901432
# 13               024_bowl          0.901425           0.908315
# ...

# %% [markdown]
# ## Per-object IoU

# %%
data = []
for obj, obj_name in CLASSES.items():
    row = {
        'Object': obj_name
    }
    for idx, model in enumerate(df['Model']):
        row[model] = df.loc[idx, f'{obj} IoU']
    data.append(row)
df_objects = pd.DataFrame(data)
df_objects
# Out:
#                    Object  resnet50_scratch  mobilenet_scratch  \
# 0              Background          0.984582           0.987368
# 1     002_master_chef_can          0.320905           0.302353
# 2         003_cracker_box          0.562131           0.592130
# 3           004_sugar_box          0.475054           0.316779
# 4     005_tomato_soup_can          0.498581           0.443537
# 5      006_mustard_bottle          0.349285           0.309721
# 6       007_tuna_fish_can          0.385393           0.374146
# 7         008_pudding_box          0.146626           0.115408
# 8         009_gelatin_box          0.489676           0.450726
# 9     010_potted_meat_can          0.418885           0.355456
# 10             011_banana          0.607147           0.586132
# 11       019_pitcher_base          0.610870           0.569914
# 12    021_bleach_cleanser          0.564933           0.522765
# 13               024_bowl          0.487252           0.524816
# ...
